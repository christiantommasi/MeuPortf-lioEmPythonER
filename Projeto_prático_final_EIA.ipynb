# %% [markdown]
# <a href="https://colab.research.google.com/github/christiantommasi/MeuPortf-lioEmPythonER/blob/main/Projeto_pr%C3%A1tico_final_EIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introdução ao projeto prático final proposto pelo professor no curso de Ciência de dados!
#
# 1. Conheça a empresa WKG:
#   Empresa do ramo de crédito que pretende diminuir sua taxa de inadimplência de 35% para no máximo 25% de inadimplência de seus clientes.
# 2. O projeto foi entregue um backup de banco de dados da base de crédito deles para ser analisada, explorada e tratada para devidas manipulações de dados corretamente.
# 3. O projeto consiste em explorar a base de clientes, encontrar as melhores oportunidades de negócios, visando disponibilizar o crédito somente para os clientes que podem arcar com o custo do empréstimo e pagar até o final, independente de adiantamento de parcelas com desconto ou não.
# O importante é a não inadimplência dos clientes!
# 4. Com o backup da base de dados em SQL em mãos que já está ativo em minha máquina, vou analisar as principais tabelas e ligações de tabelas para a base.
# 5. Após uma análise minuciosa em estatística e probabilidade, irei analisar os clientes com maior probabilidade de obterem empréstimos e pagarem todo o crédito até o final com algoritmos complexos de Machine Learning em Python para o projeto.
# 6. Pretendo no final do projeto, disponibilizar uma apresentação do projeto em Tableau para melhor apresentação da proposta de negócios solicitada!
#
#
# #7. Essa é a introdução do que espero obter e manipular com os dados do projeto final!

# %% [markdown]
# Carregando as bibliotecas necessárias para o projeto final!
